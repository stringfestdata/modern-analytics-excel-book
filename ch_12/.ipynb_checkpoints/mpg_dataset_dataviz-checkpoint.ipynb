# %%
import pandas as pd
import seaborn as sns

df = pd.read_excel('star.xlsx')

# %%
sns.pairplot(df)

# %%
sns.pairplot(contestants[['pre', 'post', 'age', 'satisfaction', 'study_hours', 'sex']],
            hue='sex')

# %%
sns.scatterplot(x='study_hours', y='post', data=contestants)
# Out:
# <AxesSubplot:xlabel='study_hours', ylabel='post'>

# %%
sns.regplot(x='study_hours', y='post', data=contestants)
# Out:
# <AxesSubplot:xlabel='study_hours', ylabel='post'>

# %%
sns.displot(data=contestants, x='post')

# %%
sns.boxplot(data=contestants, x='post')
# Out:
# <AxesSubplot:xlabel='post'>

# %%
sns.stripplot(data=contestants, x='post')
# Out:
# <AxesSubplot:xlabel='post'>
